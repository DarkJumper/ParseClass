# %%
import readFile

# %%
filepath = "/Users/peterschwarz/VS Code Projekte/ParseClass/elektrolyse_20200326.csv"

# %%
input = WorkWithFile(read, filepath)
input.execute()
# Out:
# 41\r\n',
#  '[PB:NODE];1;FBSLBLT;E12051\r\n',
#  '[PB:NODE];1;FBSLBLT;E12061\r\n',
#  '[PB:NODE];1;FBSLBLT;E12071\r\n',
#  '[PB:NODE];1;FBSLBLT;E12081\r\n',
#  '[PB:NODE];1;FBSLBLT;E12091\r\n',
#  '[PB:NODE];1;FBSLBLT;E12101\r\n',
#  '[PB:NODE];1;FBSLBLT;E12111\r\n',
#  '[PB:NODE];1;FBSLBLT;E12121\r\n',
#  '[PB:NODE];1;FBSLBLT;E12131\r\n',
#  '[PB:NODE];1;FBSLBLT;E12001\r\n',
#  '[PB:NODE];1;FBSLBLT;E12002\r\n',
#  '[PB:NODE];1;FBSLBLT;HS12000\r\n',
#  '[PB:NODE];1;FBSLBLT;S12000\r\n',
#  '[PB:NODE];1;FBSLBLT;S12011\r\n',
#  '[PB:NODE];1;FBSLBLT;S12021\r\n',
#  '[PB:NODE];1;FBSLBLT;S12031\r\n',
#  '[PB:NODE];1;FBSLBLT;S12041\r\n',
#  '[PB:NODE];1;FBSLBLT;S12051\r\n',
#  '[PB:NODE];1;FBSLBLT;S12061\r\n',
#  '[PB:NODE];1;FBSLBLT;S12071\r\n',
#  '[PB:NODE];1;FBSLBLT;S12081\r\n',
#  '[PB:NODE];1;FBSLBLT;S12091\r\n',
#  '[PB:NODE];1;FBSLBLT;S12101\r\n',
#  '[PB:NODE];1;FBSLBLT;S12111\r\n',
#  '[PB:NODE];1;FBSLBLT;S12121\r\n',
#  '[PB:NODE];1;FBSLBLT;S12131\r\n',
#  '[PB:NODE];1;FBSLBLT;H12001\r\n',
#  '[PB:NODE];1;FBSLBLT;H12002\r\n',
#  '[PB:NODE];1;FBSLBLT;X1201_2\r\n',
#  '[PB:NODE];1;FBSLBLT;X1203\r\n',
#  '[PB:NODE];1;PABLT;PS17_Serie_3\r\n',
#  '[PB:NODE];1;FBSLBLT;E13011\r\n',
#  '[PB:NODE];1;FBSLBLT;E13021\r\n',
#  '[PB:NODE];1;FBSLBLT;E13031\r\n',
#  '[PB:NODE];1;FBSLBLT;E13041\r\n',
#  '[PB:NODE];1;FBSLBLT;E13051\r\n',
#  '[PB:NODE];1;FBSLBLT;E13061\r\n',
#  '[PB:NODE];1;FBSLBLT;E13071\r\n',
#  '[PB:NODE];1;FBSLBLT;E13081\r\n',
#  '[PB:NODE];1;FBSLBLT;E13091\r\n',
#  '[PB:NODE];1;FBSLBLT;E13101\r\n',
#  '[PB:NODE];1;FBSLBLT;E13111\r\n',
#  '[PB:NODE];1;FBSLBLT;E13121\r\n',
#  '[PB:NODE];1;FBSLBLT;E13131\r\n',
#  '[PB:NODE];1;FBSLBLT;E13001\r\n',
#  '[PB:NODE];1;FBSLBLT;E13002\r\n',
#  '[PB:NODE];1;FBSLBLT;S13011\r\n',
#  '[PB:NODE];1;FBSLBLT;S13021\r\n',
#  '[PB:NODE];1;FBSLBLT;S13031\r\n',
#  '[PB:NODE];1;FBSLBLT;S13041\r\n',
#  '[PB:NODE];1;FBSLBLT;S13051\r\n',
#  '[PB:NODE];1;FBSLBLT;S13061\r\n',
#  '[PB:NODE];1;FBSLBLT;S13071\r\n',
#  '[PB:NODE];1;FBSLBLT;S13081\r\n',
#  '[PB:NODE];1;FBSLBLT;S13091\r\n',
#  '[PB:NODE];1;FBSLBLT;S13101\r\n',
#  '[PB:NODE];1;FBSLBLT;S13111\r\n',
#  '[PB:NODE];1;FBSLBLT;S13121\r\n',
#  '[PB:NODE];1;FBSLBLT;S13131\r\n',
#  '[PB:NODE];1;FBSLBLT;HS13000\r\n',
#  '[PB:NODE];1;FBSLBLT;H13001\r\n',
#  '[PB:NODE];1;FBSLBLT;H13002\r\n',
#  '[PB:NODE];1;FBSLBLT;X1301_2\r\n',
#  '[PB:NODE];1;FBSLBLT;X1303\r\n',
#  '[PB:NODE];1;FBSLBLT;S13000\r\n',
#  '[PB:NODE];1;FBSLBLT;S153011\r\n',
#  '[PB:NODE];1;FBSLBLT;S153021\r\n',
#  '[PB:NODE];1;FBSLBLT;S153031\r\n',
#  '[PB:NODE];1;FBSLBLT;S153041\r\n',
#  '[PB:NODE];1;FBSLBLT;S153051\r\n',
#  '[PB:NODE];1;FBSLBLT;S153061\r\n',
#  '[PB:NODE];1;FBSLBLT;S153071\r\n',
#  '[PB:NODE];1;FBSLBLT;S153081\r\n',
#  '[PB:NODE];1;FBSLBLT;S153091\r\n',
#  '[PB:NODE];1;FBSLBLT;S153101\r\n',
#  '[PB:NODE];1;FBSLBLT;S153111\r\n',
#  '[PB:NODE];1;FBSLBLT;S153121\r\n',
#  '[PB:NODE];1;FBSLBLT;S153131\r\n',
#  '[PB:NODE];1;TASKBLT_RED;PS17_Ser_4\r\n',
#  '[PB:NODE];1;PABLT;PS17_Serie_4\r\n',
#  '[PB:NODE];1;FBSLBLT;E14011\r\n',
#  '[PB:NODE];1;FBSLBLT;E14021\r\n',
#  '[PB:NODE];1;FBSLBLT;E14031\r\n',
#  '[PB:NODE];1;FBSLBLT;E14041\r\n',
#  '[PB:NODE];1;FBSLBLT;E14051\r\n',
#  '[PB:NODE];1;FBSLBLT;E14061\r\n',
#  '[PB:NODE];1;FBSLBLT;E14071\r\n',
#  '[PB:NODE];1;FBSLBLT;E14081\r\n',
#  '[PB:NODE];1;FBSLBLT;E14091\r\n',
#  '[PB:NODE];1;FBSLBLT;E14101\r\n',
#  '[PB:NODE];1;FBSLBLT;E14111\r\n',
#  '[PB:NODE];1;FBSLBLT;E14121\r\n',
#  '[PB:NODE];1;FBSLBLT;E14131\r\n',
#  '[PB:NODE];1;FBSLBLT;E14001\r\n',
#  '[PB:NODE];1;FBSLBLT;E14002\r\n',
#  '[PB:NODE];1;FBSLBLT;HS14000\r\n',
#  '[PB:NODE];1;FBSLBLT;H14001\r\n',
#  '[PB:NODE];1;FBSLBLT;H14002\r\n',
#  '[PB:NODE];1;FBSLBLT;S14000\r\n',
#  '[PB:NODE];1;FBSLBLT;S14011\r\n',
#  '[PB:NODE];1;FBSLBLT;S14021\r\n',
#  '[PB:NODE];1;FBSLBLT;S14031\r\n',
#  '[PB:NODE];1;FBSLBLT;S14041\r\n',
#  '[PB:NODE];1;FBSLBLT;S14051\r\n',
#  '[PB:NODE];1;FBSLBLT;S14061\r\n',
#  '[PB:NODE];1;FBSLBLT;S14071\r\n',
#  '[PB:NODE];1;FBSLBLT;S14081\r\n',
#  '[PB:NODE];1;FBSLBLT;S14091\r\n',
#  '[PB:NODE];1;FBSLBLT;S14101\r\n',
#  '[PB:NODE];1;FBSLBLT;S14111\r\n',
#  '[PB:NODE];1;FBSLBLT;S14121\r\n',
#  '[PB:NODE];1;FBSLBLT;S14131\r\n',
#  '[PB:NODE];1;FBSLBLT;X14002\r\n',
#  '[PB:NODE];1;PABLT;Allgem_4\r\n',
#  '[PB:NODE];1;FBSLBLT;S800_Feld_31\r\n',
#  '[PB:NODE];1;FBSLBLT;S800_Feld_38\r\n',
#  '[PB:NODE];1;FBSLBLT;S800_Feld_39\r\n',
#  '[PB:NODE];1;TASKBLT_RED;PS17_Ser_5_6\r\n',
#  '[PB:NODE];1;PABLT;Allgem_5_6\r\n',
#  '[PB:NODE];1;FBSLBLT;S800_Feld_33\r\n',
#  '[PB:NODE];1;FBSLBLT;S800_Feld_36\r\n',
#  '[PB:NODE];1;FBSLBLT;S800_Feld_37\r\n',
#  '[PB:NODE];1;FBSLBLT;S800_Feld_44\r\n',
#  '[PB:NODE];1;FBSLBLT;S800_Feld_45\r\n',
#  '[PB:NODE];1;FBSLBLT;S800_Feld_35\r\n',
#  '[PB:NODE];1;FBSLBLT;S5_Handumsch\r\n',
#  '[PB:NODE];1;PABLT;PS17_Serie_5\r\n',
#  '[PB:NODE];1;FBSLBLT;E15011\r\n',
#  '[PB:NODE];1;FBSLBLT;E15021\r\n',
#  '[PB:NODE];1;FBSLBLT;E15031\r\n',
#  '[PB:NODE];1;FBSLBLT;E15041\r\n',
#  '[PB:NODE];1;FBSLBLT;E15051\r\n',
#  '[PB:NODE];1;FBSLBLT;E15061\r\n',
#  '[PB:NODE];1;FBSLBLT;E15071\r\n',
#  '[PB:NODE];1;FBSLBLT;E15081\r\n',
#  '[PB:NODE];1;FBSLBLT;E15091\r\n',
#  '[PB:NODE];1;FBSLBLT;E15101\r\n',
#  '[PB:NODE];1;FBSLBLT;E15111\r\n',
#  '[PB:NODE];1;FBSLBLT;E15121\r\n',
#  '[PB:NODE];1;FBSLBLT;E15131\r\n',
#  '[PB:NODE];1;FBSLBLT;E15001\r\n',
#  '[PB:NODE];1;FBSLBLT;E15002\r\n',
#  '[PB:NODE];1;FBSLBLT;HS15000\r\n',
#  '[PB:NODE];1;FBSLBLT;H15001\r\n',
#  '[PB:NODE];1;FBSLBLT;H15002\r\n',
#  '[PB:NODE];1;FBSLBLT;S15000\r\n',
#  '[PB:NODE];1;FBSLBLT;S15011\r\n',
#  '[PB:NODE];1;FBSLBLT;S15021\r\n',
#  '[PB:NODE];1;FBSLBLT;S15031\r\n',
#  '[PB:NODE];1;FBSLBLT;S15041\r\n',
#  '[PB:NODE];1;FBSLBLT;S15051\r\n',
#  '[PB:NODE];1;FBSLBLT;S15061\r\n',
#  '[PB:NODE];1;FBSLBLT;S15071\r\n',
#  '[PB:NODE];1;FBSLBLT;S15081\r\n',
#  '[PB:NODE];1;FBSLBLT;S15091\r\n',
#  '[PB:NODE];1;FBSLBLT;S15101\r\n',
#  '[PB:NODE];1;FBSLBLT;S15111\r\n',
#  '[PB:NODE];1;FBSLBLT;S15121\r\n',
#  '[PB:NODE];1;FBSLBLT;S15131\r\n',
#  '[PB:NODE];1;FBSLBLT;S155061\r\n',
#  '[PB:NODE];1;FBSLBLT;S155071\r\n',
#  '[PB:NODE];1;FBSLBLT;S155081\r\n',
#  '[PB:NODE];1;FBSLBLT;S155091\r\n',
#  '[PB:NODE];1;FBSLBLT;S155101\r\n',
#  '[PB:NODE];1;FBSLBLT;S155111\r\n',
#  '[PB:NODE];1;FBSLBLT;X15002\r\n',
#  '[PB:NODE];1;PABLT;PS17_Serie_6\r\n',
#  '[PB:NODE];1;FBSLBLT;E16011\r\n',
#  '[PB:NODE];1;FBSLBLT;E16021\r\n',
#  '[PB:NODE];1;FBSLBLT;E16031\r\n',
#  '[PB:NODE];1;FBSLBLT;E16041\r\n',
#  '[PB:NODE];1;FBSLBLT;E16051\r\n',
#  '[PB:NODE];1;FBSLBLT;E16061\r\n',
#  '[PB:NODE];1;FBSLBLT;E16071\r\n',
#  '[PB:NODE];1;FBSLBLT;E16081\r\n',
#  '[PB:NODE];1;FBSLBLT;E16091\r\n',
#  '[PB:NODE];1;FBSLBLT;E16101\r\n',
#  '[PB:NODE];1;FBSLBLT;E16111\r\n',
#  '[PB:NODE];1;FBSLBLT;E16121\r\n',
#  '[PB:NODE];1;FBSLBLT;E16131\r\n',
#  '[PB:NODE];1;FBSLBLT;E16001\r\n',
#  '[PB:NODE];1;FBSLBLT;E16002\r\n',
#  '[PB:NODE];1;FBSLBLT;HS16000\r\n',
#  '[PB:NODE];1;FBSLBLT;H16001\r\n',
#  '[PB:NODE];1;FBSLBLT;H16002\r\n',
#  '[PB:NODE];1;FBSLBLT;S16000\r\n',
#  '[PB:NODE];1;FBSLBLT;S16011\r\n',
#  '[PB:NODE];1;FBSLBLT;S16021\r\n',
#  '[PB:NODE];1;FBSLBLT;S16031\r\n',
#  '[PB:NODE];1;FBSLBLT;S16041\r\n',
#  '[PB:NODE];1;FBSLBLT;S16051\r\n',
#  '[PB:NODE];1;FBSLBLT;S16061\r\n',
#  '[PB:NODE];1;FBSLBLT;S16071\r\n',
#  '[PB:NODE];1;FBSLBLT;S16081\r\n',
#  '[PB:NODE];1;FBSLBLT;S16091\r\n',
#  '[PB:NODE];1;FBSLBLT;S16101\r\n',
#  '[PB:NODE];1;FBSLBLT;S16111\r\n',
#  '[PB:NODE];1;FBSLBLT;S16121\r\n',
#  '[PB:NODE];1;FBSLBLT;S16131\r\n',
#  '[PB:NODE];1;FBSLBLT;X16001_2\r\n',
#  '[PB:NODE];1;TASKBLT_RED;PS17_Ser_7_8\r\n',
#  '[PB:NODE];1;PABLT;Allgem_7_8\r\n',
#  '[PB:NODE];1;FBSLBLT;S800_Feld_40\r\n',
#  '[PB:NODE];1;FBSLBLT;S800_Feld_41\r\n',
#  '[PB:NODE];1;FBSLBLT;S800_Feld_42\r\n',
#  '[PB:NODE];1;FBSLBLT;S800_Feld_43\r\n',
#  '[PB:NODE];1;FBSLBLT;S800_Feld_47\r\n',
#  '[PB:NODE];1;FBSLBLT;S800_Feld_49\r\n',
#  '[PB:NODE];1;PABLT;PS17_Serie_7\r\n',
#  '[PB:NODE];1;FBSLBLT;E17011\r\n',
#  '[PB:NODE];1;FBSLBLT;E17021\r\n',
#  '[PB:NODE];1;FBSLBLT;E17031\r\n',
#  '[PB:NODE];1;FBSLBLT;E17041\r\n',
#  '[PB:NODE];1;FBSLBLT;E17051\r\n',
#  '[PB:NODE];1;FBSLBLT;E17061\r\n',
#  '[PB:NODE];1;FBSLBLT;E17071\r\n',
#  '[PB:NODE];1;FBSLBLT;E17081\r\n',
#  '[PB:NODE];1;FBSLBLT;E17091\r\n',
#  '[PB:NODE];1;FBSLBLT;E17101\r\n',
#  '[PB:NODE];1;FBSLBLT;E17111\r\n',
#  '[PB:NODE];1;FBSLBLT;E17121\r\n',
#  '[PB:NODE];1;FBSLBLT;E17131\r\n',
#  '[PB:NODE];1;FBSLBLT;E17141\r\n',
#  '[PB:NODE];1;FBSLBLT;E17151\r\n',
#  '[PB:NODE];1;FBSLBLT;HS17000\r\n',
#  '[PB:NODE];1;FBSLBLT;H17001\r\n',
#  '[PB:NODE];1;FBSLBLT;H17002\r\n',
#  '[PB:NODE];1;FBSLBLT;S17000\r\n',
#  '[PB:NODE];1;FBSLBLT;S17011\r\n',
#  '[PB:NODE];1;FBSLBLT;S17021\r\n',
#  '[PB:NODE];1;FBSLBLT;S17031\r\n',
#  '[PB:NODE];1;FBSLBLT;S17041\r\n',
#  '[PB:NODE];1;FBSLBLT;S17051\r\n',
#  '[PB:NODE];1;FBSLBLT;S17061\r\n',
#  '[PB:NODE];1;FBSLBLT;S17071\r\n',
#  '[PB:NODE];1;FBSLBLT;S17081\r\n',
#  '[PB:NODE];1;FBSLBLT;S17091\r\n',
#  '[PB:NODE];1;FBSLBLT;S17101\r\n',
#  '[PB:NODE];1;FBSLBLT;S17111\r\n',
#  '[PB:NODE];1;FBSLBLT;S17121\r\n',
#  '[PB:NODE];1;FBSLBLT;S17131\r\n',
#  '[PB:NODE];1;FBSLBLT;X17001_2\r\n',
#  '[PB:NODE];1;FBSLBLT;S157011\r\n',
#  '[PB:NODE];1;FBSLBLT;S157021\r\n',
#  '[PB:NODE];1;FBSLBLT;S157031\r\n',
#  '[PB:NODE];1;FBSLBLT;S157041\r\n',
#  '[PB:NODE];1;FBSLBLT;S157051\r\n',
#  '[PB:NODE];1;FBSLBLT;S157061\r\n',
#  '[PB:NODE];1;FBSLBLT;S157071\r\n',
#  '[PB:NODE];1;FBSLBLT;S157081\r\n',
#  '[PB:NODE];1;FBSLBLT;S157091\r\n',
#  '[PB:NODE];1;FBSLBLT;S157101\r\n',
#  '[PB:NODE];1;FBSLBLT;S157111\r\n',
#  '[PB:NODE];1;FBSLBLT;S157121\r\n',
#  '[PB:NODE];1;FBSLBLT;S157131\r\n',
#  '[PB:NODE];1;PABLT;PS17_Serie_8\r\n',
#  '[PB:NODE];1;FBSLBLT;E18041\r\n',
#  '[PB:NODE];1;FBSLBLT;E18051\r\n',
#  '[PB:NODE];1;FBSLBLT;E18061\r\n',
#  '[PB:NODE];1;FBSLBLT;E18071\r\n',
#  '[PB:NODE];1;FBSLBLT;E18081\r\n',
#  '[PB:NODE];1;FBSLBLT;E18091\r\n',
#  '[PB:NODE];1;FBSLBLT;E18101\r\n',
#  '[PB:NODE];1;FBSLBLT;E18111\r\n',
#  '[PB:NODE];1;FBSLBLT;E18121\r\n',
#  '[PB:NODE];1;FBSLBLT;E18131\r\n',
#  '[PB:NODE];1;FBSLBLT;E18001\r\n',
#  '[PB:NODE];1;FBSLBLT;E18002\r\n',
#  '[PB:NODE];1;FBSLBLT;HS18000\r\n',
#  '[PB:NODE];1;FBSLBLT;H18001\r\n',
#  '[PB:NODE];1;FBSLBLT;H18002\r\n',
#  '[PB:NODE];1;FBSLBLT;S18000\r\n',
#  '[PB:NODE];1;FBSLBLT;S18041\r\n',
#  '[PB:NODE];1;FBSLBLT;S18051\r\n',
#  '[PB:NODE];1;FBSLBLT;S18061\r\n',
#  '[PB:NODE];1;FBSLBLT;S18071\r\n',
#  '[PB:NODE];1;FBSLBLT;S18081\r\n',
#  '[PB:NODE];1;FBSLBLT;S18091\r\n',
#  '[PB:NODE];1;FBSLBLT;S18101\r\n',
#  '[PB:NODE];1;FBSLBLT;S18111\r\n',
#  '[PB:NODE];1;FBSLBLT;S18121\r\n',
#  '[PB:NODE];1;FBSLBLT;S18131\r\n',
#  '[PB:NODE];1;FBSLBLT;X18001\r\n',
#  '[PB:NODE];1;FBSLBLT;X18002\r\n',
#  '[PB:NODE];1;FBSLBLT;S158041\r\n',
#  '[PB:NODE];1;FBSLBLT;S158051\r\n',
#  '[PB:NODE];1;FBSLBLT;S158061\r\n',
#  '[PB:NODE];1;FBSLBLT;S158071\r\n',
#  '[PB:NODE];1;FBSLBLT;S158081\r\n',
#  '[PB:NODE];1;FBSLBLT;S158091\r\n',
#  '[PB:NODE];1;FBSLBLT;S158101\r\n',
#  '[PB:NODE];1;FBSLBLT;S158111\r\n',
#  '[PB:NODE];1;FBSLBLT;S158121\r\n',
#  '[PB:NODE];1;FBSLBLT;S158131\r\n',
#  '[PB:NODE];1;MSREXPBLT_RED;PS19\r\n',
#  '[PB:NODE];1;TASKBLT_RED;PS19_Task_1\r\n',
#  '[PB:NODE];1;PABLT;NMPumpen_MES\r\n',
#  '[PB:NODE];1;FBSLBLT;T1818\r\n',
#  '[PB:NODE];1;PABLT;NMPumpen\r\n',
#  '[PB:NODE];1;FBSLBLT;S1811\r\n',
#  '[PB:NODE];1;FBSLBLT;S1812\r\n',
#  '[PB:NODE];1;FBSLBLT;S1813\r\n',
#  '[PB:NODE];1;FBSLBLT;S1816\r\n',
#  '[PB:NODE];1;PABLT;Test\r\n',
#  '[PB:NODE];1;FBSLBLT;Ein_Test\r\n',
#  '[PB:NODE];1;FBSLBLT;Testmotor\r\n',
#  '[PB:NODE];1;FBSLBLT;H2217_EDC\r\n',
#  '[PB:NODE];1;PABLT;Allg.Messg.\r\n',
#  '[PB:NODE];1;FBSLBLT;F1032\r\n',
#  '[PB:NODE];1;FBSLBLT;F1919\r\n',
#  '[PB:NODE];1;FBSLBLT;Hupe\r\n',
#  '[PB:NODE];1;FBSLBLT;X1956_PS19\r\n',
#  '[PB:NODE];1;FBSLBLT;X001001\r\n',
#  '[PB:NODE];1;FBSLBLT;X001002\r\n',
#  '[PB:NODE];1;FBSLBLT;X001003\r\n',
#  '[PB:NODE];1;FBSLBLT;X001003.1\r\n',
#  '[PB:NODE];1;FBSLBLT;X001004\r\n',
#  '[PB:NODE];1;FBSLBLT;X001005\r\n',
#  '[PB:NODE];1;FBSLBLT;X001006\r\n',
#  '[PB:NODE];1;FBSLBLT;X001010\r\n',
#  '[PB:NODE];1;FBSLBLT;X001011\r\n',
#  '[PB:NODE];1;FBSLBLT;X001012\r\n',
#  '[PB:NODE];1;PABLT;Diagnose\r\n',
#  '[PB:NODE];1;FBSLBLT;System\r\n',
#  '[PB:NODE];1;FBSLBLT;S800_R23A01\r\n',
#  '[PB:NODE];1;FBSLBLT;S800_R23A02\r\n',
#  '[PB:NODE];1;FBSLBLT;S800_Feld_1\r\n',
#  '[PB:NODE];1;FBSLBLT;S800_Feld_2\r\n',
#  '[PB:NODE];1;FBSLBLT;S800_Feld_3\r\n',
#  '[PB:NODE];1;FBSLBLT;S800_Feld_9\r\n',
#  '[PB:NODE];1;FBSLBLT;S800_Feld_10\r\n',
#  '[PB:NODE];1;FBSLBLT;S800_Feld_11\r\n',
#  '[PB:NODE];1;FBSLBLT;S800_F71A00\r\n',
#  '[PB:NODE];1;FBSLBLT;S800_F76A00\r\n',
#  '[PB:NODE];1;PABLT;KCl-Reinsole\r\n',
#  '[PB:NODE];1;FBSLBLT;UZ1916\r\n',
#  '[PB:NODE];1;FBSLBLT;E1912\r\n',
#  '[PB:NODE];1;FBSLBLT;E1913\r\n',
#  '[PB:NODE];1;FBSLBLT;F1907\r\n',
#  '[PB:NODE];1;FBSLBLT;F1910\r\n',
#  '[PB:NODE];1;FBSLBLT;F1911\r\n',
#  '[PB:NODE];1;FBSLBLT;F1916\r\n',
#  '[PB:NODE];1;FBSLBLT;L1900\r\n',
#  '[PB:NODE];1;FBSLBLT;L1905\r\n',
#  '[PB:NODE];1;FBSLBLT;L1906\r\n',
#  '[PB:NODE];1;FBSLBLT;L1906_OUT\r\n',
#  '[PB:NODE];1;FBSLBLT;L1923\r\n',
#  '[PB:NODE];1;FBSLBLT;L1924\r\n',
#  '[PB:NODE];1;FBSLBLT;L1958\r\n',
#  '[PB:NODE];1;FBSLBLT;L1964\r\n',
#  '[PB:NODE];1;FBSLBLT;LC1968\r\n',
#  '[PB:NODE];1;FBSLBLT;L1969\r\n',
#  '[PB:NODE];1;FBSLBLT;Q1908\r\n',
#  '[PB:NODE];1;FBSLBLT;Q1909\r\n',
#  '[PB:NODE];1;FBSLBLT;QD1910\r\n',
#  '[PB:NODE];1;FBSLBLT;Q1915\r\n',
#  '[PB:NODE];1;FBSLBLT;S1914\r\n',
#  '[PB:NODE];1;FBSLBLT;S1915\r\n',
#  '[PB:NODE];1;FBSLBLT;TD1912\r\n',
#  '[PB:NODE];1;FBSLBLT;T1913\r\n',
#  '[PB:NODE];1;FBSLBLT;T1914\r\n',
#  '[PB:NODE];1;FBSLBLT;Y1919\r\n',
#  '[PB:NODE];1;FBSLBLT;T1916\r\n',
#  '[PB:NODE];1;FBSLBLT;T1917\r\n',
#  '[PB:NODE];1;FBSLBLT;T1918\r\n',
#  '[PB:NODE];1;FBSLBLT;P-2607_Logik\r\n',
#  '[PB:NODE];1;FBSLBLT;P-2607A\r\n',
#  '[PB:NODE];1;FBSLBLT;P-2607R\r\n',
#  '[PB:NODE];1;FBSLBLT;P-2609\r\n',
#  '[PB:NODE];1;FBSLBLT;Y1915\r\n',
#  '[PB:NODE];1;FBSLBLT;Y1916\r\n',
#  '[PB:NODE];1;FBSLBLT;Y1917\r\n',
#  '[PB:NODE];1;FBSLBLT;Y1918\r\n',
#  '[PB:NODE];1;PABLT;KCl-Rücksole\r\n',
#  '[PB:NODE];1;FBSLBLT;E1928\r\n',
#  '[PB:NODE];1;FBSLBLT;E1929\r\n',
#  '[PB:NODE];1;FBSLBLT;E1951\r\n',
#  '[PB:NODE];1;FBSLBLT;E1952\r\n',
#  '[PB:NODE];1;FBSLBLT;F1955\r\n',
#  '[PB:NODE];1;FBSLBLT;F1966\r\n',
#  '[PB:NODE];1;FBSLBLT;H1965\r\n',
#  '[PB:NODE];1;FBSLBLT;L1901\r\n',
#  '[PB:NODE];1;FBSLBLT;L1901_OUT\r\n',
#  '[PB:NODE];1;FBSLBLT;Summe\r\n',
#  '[PB:NODE];1;FBSLBLT;L1951\r\n',
#  '[PB:NODE];1;FBSLBLT;L1961\r\n',
#  '[PB:NODE];1;FBSLBLT;L1962\r\n',
#  '[PB:NODE];1;FBSLBLT;L1963\r\n',
#  '[PB:NODE];1;FBSLBLT;P2701A\r\n',
#  '[PB:NODE];1;FBSLBLT;P2701R\r\n',
#  '[PB:NODE];1;FBSLBLT;Q1951\r\n',
#  '[PB:NODE];1;FBSLBLT;Q1952\r\n',
#  '[PB:NODE];1;FBSLBLT;Q1953\r\n',
#  '[PB:NODE];1;FBSLBLT;P1958\r\n',
#  '[PB:NODE];1;FBSLBLT;P1959\r\n',
#  '[PB:NODE];1;FBSLBLT;P1963\r\n',
#  '[PB:NODE];1;FBSLBLT;T1969\r\n',
#  '[PB:NODE];1;FBSLBLT;Y1955\r\n',
#  '[PB:NODE];1;FBSLBLT;P9407A\r\n',
#  '[PB:NODE];1;FBSLBLT;P9407R\r\n',
#  '[PB:NODE];1;FBSLBLT;S1814\r\n',
#  '[PB:NODE];1;FBSLBLT;S1815\r\n',
#  '[PB:NODE];1;FBSLBLT;S1951\r\n',
#  '[PB:NODE];1;FBSLBLT;S1952\r\n',
#  '[PB:NODE];1;FBSLBLT;S1953\r\n',
#  '[PB:NODE];1;FBSLBLT;S1953_1\r\n',
#  '[PB:NODE];1;FBSLBLT;S1954\r\n',
#  '[PB:NODE];1;FBSLBLT;S1954_1\r\n',
#  '[PB:NODE];1;FBSLBLT;S1955\r\n',
#  '[PB:NODE];1;FBSLBLT;S1956\r\n',
#  '[PB:NODE];1;FBSLBLT;S1957\r\n',
#  '[PB:NODE];1;FBSLBLT;S1958\r\n',
#  '[PB:NODE];1;FBSLBLT;S1959\r\n',
#  '[PB:NODE];1;FBSLBLT;T1905\r\n',
#  '[PB:NODE];1;FBSLBLT;T1950\r\n',
#  '[PB:NODE];1;FBSLBLT;T1951\r\n',
#  '[PB:NODE];1;FBSLBLT;T1952\r\n',
#  '[PB:NODE];1;FBSLBLT;T1967\r\n',
#  '[PB:NODE];1;FBSLBLT;U1951\r\n',
#  '[PB:NODE];1;FBSLBLT;Y1920\r\n',
#  '[PB:NODE];1;FBSLBLT;Y1951\r\n',
#  '[PB:NODE];1;FBSLBLT;Y1953\r\n',
#  '[PB:NODE];1;FBSLBLT;Y1954\r\n',
#  '[PB:NODE];1;FBSLBLT;Y1956\r\n',
#  '[PB:NODE];1;PABLT;KCl-EntChlor\r\n',
#  '[PB:NODE];1;FBSLBLT;F1967\r\n',
#  '[PB:NODE];1;FBSLBLT;L1965\r\n',
#  '[PB:NODE];1;FBSLBLT;L1966\r\n',
#  '[PB:NODE];1;FBSLBLT;L1967\r\n',
#  '[PB:NODE];1;PABLT;Reinstwasser\r\n',
#  '[PB:NODE];1;FBSLBLT;L1930\r\n',
#  '[PB:NODE];1;FBSLBLT;F1997\r\n',
#  '[PB:NODE];1;FBSLBLT;L1985\r\n',
#  '[PB:NODE];1;FBSLBLT;L1909\r\n',
#  '[PB:NODE];1;FBSLBLT;S1921\r\n',
#  '[PB:NODE];1;FBSLBLT;S1922\r\n',
#  '[PB:NODE];1;PABLT;NaCl_Anoly\r\n',
#  '[PB:NODE];1;FBSLBLT;EI1000\r\n',
#  '[PB:NODE];1;FBSLBLT;EI1002\r\n',
#  '[PB:NODE];1;FBSLBLT;EI1985\r\n',
#  '[PB:NODE];1;FBSLBLT;EI1986\r\n',
#  '[PB:NODE];1;FBSLBLT;P2301A\r\n',
#  '[PB:NODE];1;FBSLBLT;P2301R\r\n',
#  '[PB:NODE];1;FBSLBLT;P2305A\r\n',
#  '[PB:NODE];1;FBSLBLT;P2305R\r\n',
#  '[PB:NODE];1;PABLT;NaCl_Rückso\r\n',
#  '[PB:NODE];1;FBSLBLT;UZ1910\r\n',
#  '[PB:NODE];1;FBSLBLT;EI1001\r\n',
#  '[PB:NODE];1;FBSLBLT;EI1003\r\n',
#  '[PB:NODE];1;FBSLBLT;P2402A\r\n',
#  '[PB:NODE];1;FBSLBLT;P2402R\r\n',
#  '[PB:NODE];1;PABLT;UZ_Alk_H2\r\n',
#  '[PB:NODE];1;FBSLBLT;L8002\r\n',
#  '[PB:NODE];1;FBSLBLT;L8004\r\n',
#  '[PB:NODE];1;FBSLBLT;UZ8006\r\n',
#  '[PB:NODE];1;FBSLBLT;UZ8007\r\n',
#  '[PB:NODE];1;PABLT;KMPumpen\r\n',
#  '[PB:NODE];1;FBSLBLT;S1521\r\n',
#  '[PB:NODE];1;FBSLBLT;S1520\r\n',
#  '[PB:NODE];1;PABLT;Sperrwasser\r\n',
#  '[PB:NODE];1;FBSLBLT;S1925\r\n',
#  '[PB:NODE];1;FBSLBLT;S1926\r\n',
#  '[PB:NODE];1;FBSLBLT;S1987\r\n',
#  '[PB:NODE];1;FBSLBLT;S1988\r\n',
#  '[PB:NODE];1;TASKBLT_RED;Hg-ARA\r\n',
#  '[PB:NODE];1;PABLT;Hg-ARA_msr\r\n',
#  '[PB:NODE];1;FBSLBLT;F6226\r\n',
#  '[PB:NODE];1;FBSLBLT;F6227\r\n',
#  '[PB:NODE];1;FBSLBLT;F6228\r\n',
#  '[PB:NODE];1;FBSLBLT;BYPASS\r\n',
#  '[PB:NODE];1;FBSLBLT;F6201\r\n',
#  '[PB:NODE];1;FBSLBLT;F6203\r\n',
#  '[PB:NODE];1;FBSLBLT;F6201V\r\n',
#  '[PB:NODE];1;FBSLBLT;F6204\r\n',
#  '[PB:NODE];1;FBSLBLT;F6205\r\n',
#  '[PB:NODE];1;FBSLBLT;F6215\r\n',
#  '[PB:NODE];1;FBSLBLT;F6218\r\n',
#  '[PB:NODE];1;FBSLBLT;F6220\r\n',
#  '[PB:NODE];1;FBSLBLT;F6222\r\n',
#  '[PB:NODE];1;FBSLBLT;F6223\r\n',
#  '[PB:NODE];1;FBSLBLT;F6224\r\n',
#  '[PB:NODE];1;FBSLBLT;F6225\r\n',
#  '[PB:NODE];1;FBSLBLT;F6229\r\n',
#  '[PB:NODE];1;FBSLBLT;FV6229\r\n',
#  '[PB:NODE];1;FBSLBLT;G6226_1\r\n',
#  '[PB:NODE];1;FBSLBLT;G6226_2\r\n',
#  '[PB:NODE];1;FBSLBLT;H6225A\r\n',
#  '[PB:NODE];1;FBSLBLT;H6225R\r\n',
#  '[PB:NODE];1;FBSLBLT;L3000\r\n',
#  '[PB:NODE];1;FBSLBLT;L6201\r\n',
#  '[PB:NODE];1;FBSLBLT;L6203\r\n',
#  '[PB:NODE];1;FBSLBLT;L6204\r\n',
#  '[PB:NODE];1;FBSLBLT;L6205\r\n',
#  '[PB:NODE];1;FBSLBLT;L6206\r\n',
#  '[PB:NODE];1;FBSLBLT;L6207\r\n',
#  '[PB:NODE];1;FBSLBLT;L6207_1\r\n',
#  '[PB:NODE];1;FBSLBLT;L6207_2\r\n',
#  '[PB:NODE];1;FBSLBLT;L6208\r\n',
#  '[PB:NODE];1;FBSLBLT;L6209\r\n',
#  '[PB:NODE];1;FBSLBLT;L6210\r\n',
#  '[PB:NODE];1;FBSLBLT;L6211\r\n',
#  '[PB:NODE];1;FBSLBLT;L6216\r\n',
#  '[PB:NODE];1;FBSLBLT;L6217\r\n',
#  '[PB:NODE];1;FBSLBLT;L6221\r\n',
#  '[PB:NODE];1;FBSLBLT;L6222\r\n',
#  '[PB:NODE];1;FBSLBLT;L6223\r\n',
#  '[PB:NODE];1;FBSLBLT;LV6223\r\n',
#  '[PB:NODE];1;FBSLBLT;L6264\r\n',
#  '[PB:NODE];1;FBSLBLT;LZ6226\r\n',
#  '[PB:NODE];1;FBSLBLT;P6204\r\n',
#  '[PB:NODE];1;FBSLBLT;P6213\r\n',
#  '[PB:NODE];1;FBSLBLT;P6214\r\n',
#  '[PB:NODE];1;FBSLBLT;P6215\r\n',
#  '[PB:NODE];1;FBSLBLT;P6216\r\n',
#  '[PB:NODE];1;FBSLBLT;PD6217\r\n',
#  '[PB:NODE];1;FBSLBLT;PD6218\r\n',
#  '[PB:NODE];1;FBSLBLT;P6251\r\n',
#  '[PB:NODE];1;FBSLBLT;Q005\r\n',
#  '[PB:NODE];1;FBSLBLT;Q6200_Res\r\n',
#  '[PB:NODE];1;FBSLBLT;Q6201\r\n',
#  '[PB:NODE];1;FBSLBLT;Q6202\r\n',
#  '[PB:NODE];1;FBSLBLT;Q6203\r\n',
#  '[PB:NODE];1;FBSLBLT;Q6204\r\n',
#  '[PB:NODE];1;FBSLBLT;Q6205\r\n',
#  '[PB:NODE];1;FBSLBLT;Q6206\r\n',
#  '[PB:NODE];1;FBSLBLT;Q6208\r\n',
#  '[PB:NODE];1;FBSLBLT;Q6209\r\n',
#  '[PB:NODE];1;FBSLBLT;UV6205\r\n',
#  '[PB:NODE];1;FBSLBLT;UV6206\r\n',
#  '[PB:NODE];1;FBSLBLT;Y6201\r\n',
#  '[PB:NODE];1;FBSLBLT;Y6202\r\n',
#  '[PB:NODE];1;PABLT;Hg-ARA_Motor\r\n',
#  '[PB:NODE];1;FBSLBLT;E1966\r\n',
#  '[PB:NODE];1;FBSLBLT;E6203\r\n',
#  '[PB:NODE];1;FBSLBLT;E6204\r\n',
#  '[PB:NODE];1;FBSLBLT;E6206\r\n',
#  '[PB:NODE];1;FBSLBLT;E6207\r\n',
#  '[PB:NODE];1;FBSLBLT;E6208\r\n',
#  '[PB:NODE];1;FBSLBLT;E6209\r\n',
#  '[PB:NODE];1;FBSLBLT;E6211\r\n',
#  '[PB:NODE];1;FBSLBLT;E6212\r\n',
#  '[PB:NODE];1;FBSLBLT;E6213\r\n',
#  '[PB:NODE];1;FBSLBLT;E6216\r\n',
#  '[PB:NODE];1;FBSLBLT;E6217\r\n',
#  '[PB:NODE];1;FBSLBLT;E6218\r\n',
#  '[PB:NODE];1;FBSLBLT;E6218_1\r\n',
#  '[PB:NODE];1;FBSLBLT;E6219\r\n',
#  '[PB:NODE];1;FBSLBLT;E6219_1\r\n',
#  '[PB:NODE];1;FBSLBLT;E6220\r\n',
#  '[PB:NODE];1;FBSLBLT;E6222\r\n',
#  '[PB:NODE];1;FBSLBLT;E6223\r\n',
#  '[PB:NODE];1;FBSLBLT;E6224\r\n',
#  '[PB:NODE];1;FBSLBLT;S6201\r\n',
#  '[PB:NODE];1;FBSLBLT;S6202\r\n',
#  '[PB:NODE];1;FBSLBLT;S6203\r\n',
#  '[PB:NODE];1;FBSLBLT;S6204\r\n',
#  '[PB:NODE];1;FBSLBLT;S6205\r\n',
#  '[PB:NODE];1;FBSLBLT;S6206\r\n',
#  '[PB:NODE];1;FBSLBLT;S6207\r\n',
#  '[PB:NODE];1;FBSLBLT;S6208\r\n',
#  '[PB:NODE];1;FBSLBLT;S6209\r\n',
#  '[PB:NODE];1;FBSLBLT;S6211\r\n',
#  '[PB:NODE];1;FBSLBLT;S6212\r\n',
#  '[PB:NODE];1;FBSLBLT;S6213\r\n',
#  '[PB:NODE];1;FBSLBLT;S6214\r\n',
#  '[PB:NODE];1;FBSLBLT;S6216\r\n',
#  ...]
