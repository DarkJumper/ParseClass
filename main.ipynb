# %%
from readFile import *
from parsingFreelance import *

# %%
filepath = "/Users/peterschwarz/VS Code Projekte/ParseClass/elektrolyse_20200326.csv"

# %%
input = WorkWithFile(read, filepath).execute()
df_parse = Freelance(input).get_data()
print(df_parse)
# Out:
# Parse Ausgeführt
# [                            0
# 0       [BEGIN_PROJECTHEADER]
# 1                 elektrolyse
# 2                 Elektrolyse
# 3           DeltaControl GmbH
# 4
# 5                           0
# 6                           0
# 7                        2011
# 8                           9
# 9                          27
# 10                          8
# 11                         34
# 12                          1
# 13                        926
# 14  Evonik Industries AG, PLT
# 15
# 16
# 17                          1
# 18                          1
# 19                          1
# 20                       2001
# 21                          1
# 22                         30
# 23                         14
# 24                         47
# 25                         31
# 26                        687
# 27                          1
# 28                         14
# 29                         12
# 30                         35
# 31                         54
# 32                        690
# 33                       2016
# 34                          1
# 35                        690
# 36                          0
# 37                          0
# 38                          0
# 39                          0
# 40                          0
# 41                          0
# 42                       3444
# 43                        965
# 44                          0
# 45                          0
# 46                          0
# 47                          1,                          0   1     2     3              4
# 0   [BEGIN_AREADEFINITION]  17  None  None           None
# 1                   [AREA]   1     !    13  Systembereich
# 2                   [AREA]   1     -    12   Kein Bereich
# 3                   [AREA]   1     A     6         Area A
# 4                   [AREA]   1     B     6         Area B
# 5                   [AREA]   1     C     6         Area C
# 6                   [AREA]   1     D     6         Area D
# 7                   [AREA]   1     E     6         Area E
# 8                   [AREA]   1     F     6         Area F
# 9                   [AREA]   1     G     6         Area G
# 10                  [AREA]   1     H     6         Area H
# 11                  [AREA]   1     I     6         Area I
# 12                  [AREA]   1     J     6         Area J
# 13                  [AREA]   1     K     6         Area K
# 14                  [AREA]   1     L     6         Area L
# 15                  [AREA]   1     M     6         Area M
# 16                  [AREA]   1     N     6         Area N
# 17                  [AREA]   1     O     6         Area O
# 18                [NOAREA]   0  None  None           None,                             0
# 0       [BEGIN_PROJECTHEADER]
# 1                 elektrolyse
# 2                 Elektrolyse
# 3           DeltaControl GmbH
# 4
# 5                           0
# 6                           0
# 7                        2011
# 8                           9
# 9                          27
# 10                          8
# 11                         34
# 12                          1
# 13                        926
# 14  Evonik Industries AG, PLT
# 15
# 16
# 17                          1
# 18                          1
# 19                          1
# 20                       2001
# 21                          1
# 22                         30
# 23                         14
# 24                         47
# 25                         31
# 26                        687
# 27                          1
# 28                         14
# 29                         12
# 30                         35
# 31                         54
# 32                        690
# 33                       2016
# 34                          1
# 35                        690
# 36                          0
# 37                          0
# 38                          0
# 39                          0
# 40                          0
# 41                          0
# 42                       3444
# 43                        965
# 44                          0
# 45                          0
# 46                          0
# 47                          1,                          0   1     2     3              4
# 0   [BEGIN_AREADEFINITION]  17  None  None           None
# 1                   [AREA]   1     !    13  Systembereich
# 2                   [AREA]   1     -    12   Kein Bereich
# 3                   [AREA]   1     A     6         Area A
# 4                   [AREA]   1     B     6         Area B
# 5                   [AREA]   1     C     6         Area C
# 6                   [AREA]   1     D     6         Area D
# 7                   [AREA]   1     E     6         Area E
# 8                   [AREA]   1     F     6         Area F
# 9                   [AREA]   1     G     6         Area G
# 10                  [AREA]   1     H     6         Area H
# 11                  [AREA]   1     I     6         Area I
# 12                  [AREA]   1     J     6         Area J
# 13                  [AREA]   1     K     6         Area K
# 14                  [AREA]   1     L     6         Area L
# 15                  [AREA]   1     M     6         Area M
# 16                  [AREA]   1     N     6         Area N
# 17                  [AREA]   1     O     6         Area O
# 18                [NOAREA]   0  None  None           None,                             0
# 0       [BEGIN_PROJECTHEADER]
# 1                 elektrolyse
# 2                 Elektrolyse
# 3           DeltaControl GmbH
# 4
# 5                           0
# 6                           0
# 7                        2011
# 8                           9
# 9                          27
# 10                          8
# 11                         34
# 12                          1
# 13                        926
# 14  Evonik Industries AG, PLT
# 15
# 16
# 17                          1
# 18                          1
# 19                          1
# 20                       2001
# 21                          1
# 22                         30
# 23                         14
# 24                         47
# 25                         31
# 26                        687
# 27                          1
# 28                         14
# 29                         12
# 30                         35
# 31                         54
# 32                        690
# 33                       2016
# 34                          1
# 35                        690
# 36                          0
# 37                          0
# 38                          0
# 39                          0
# 40                          0
# 41                          0
# 42                       3444
# 43                        965
# 44                          0
# 45                          0
# 46                          0
# 47                          1,                          0   1     2     3              4
# 0   [BEGIN_AREADEFINITION]  17  None  None           None
# 1                   [AREA]   1     !    13  Systembereich
# 2                   [AREA]   1     -    12   Kein Bereich
# 3                   [AREA]   1     A     6         Area A
# 4                   [AREA]   1     B     6         Area B
# 5                   [AREA]   1     C     6         Area C
# 6                   [AREA]   1     D     6         Area D
# 7                   [AREA]   1     E     6         Area E
# 8                   [AREA]   1     F     6         Area F
# 9                   [AREA]   1     G     6         Area G
# 10                  [AREA]   1     H     6         Area H
# 11                  [AREA]   1     I     6         Area I
# 12                  [AREA]   1     J     6         Area J
# 13                  [AREA]   1     K     6         Area K
# 14                  [AREA]   1     L     6         Area L
# 15                  [AREA]   1     M     6         Area M
# 16                  [AREA]   1     N     6         Area N
# 17                  [AREA]   1     O     6         Area O
# 18                [NOAREA]   0  None  None           None,                             0
# 0       [BEGIN_PROJECTHEADER]
# 1                 elektrolyse
# 2                 Elektrolyse
# 3           DeltaControl GmbH
# 4
# 5                           0
# 6                           0
# 7                        2011
# 8                           9
# 9                          27
# 10                          8
# 11                         34
# 12                          1
# 13                        926
# 14  Evonik Industries AG, PLT
# 15
# 16
# 17                          1
# 18                          1
# 19                          1
# 20                       2001
# 21                          1
# 22                         30
# 23                         14
# 24                         47
# 25                         31
# 26                        687
# 27                          1
# 28                         14
# 29                         12
# 30                         35
# 31                         54
# 32                        690
# 33                       2016
# 34                          1
# 35                        690
# 36                          0
# 37                          0
# 38                          0
# 39                          0
# 40                          0
# 41                          0
# 42                       3444
# 43                        965
# 44                          0
# 45                          0
# 46                          0
# 47                          1,                          0   1     2     3              4
# 0   [BEGIN_AREADEFINITION]  17  None  None           None
# 1                   [AREA]   1     !    13  Systembereich
# 2                   [AREA]   1     -    12   Kein Bereich
# 3                   [AREA]   1     A     6         Area A
# 4                   [AREA]   1     B     6         Area B
# 5                   [AREA]   1     C     6         Area C
# 6                   [AREA]   1     D     6         Area D
# 7                   [AREA]   1     E     6         Area E
# 8                   [AREA]   1     F     6         Area F
# 9                   [AREA]   1     G     6         Area G
# 10                  [AREA]   1     H     6         Area H
# 11                  [AREA]   1     I     6         Area I
# 12                  [AREA]   1     J     6         Area J
# 13                  [AREA]   1     K     6         Area K
# 14                  [AREA]   1     L     6         Area L
# 15                  [AREA]   1     M     6         Area M
# 16                  [AREA]   1     N     6         Area N
# 17                  [AREA]   1     O     6         Area O
# 18                [NOAREA]   0  None  None           None]
